# %% [markdown]
# <a href="https://colab.research.google.com/github/RojaCM/Complete-Python-3-Bootcamp/blob/master/DEX%20data%20conv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_json('Contents.json')

# %%
data
# Out:
#             took  timed_out  _shards  \
# total         25      False      1.0
# successful    25      False      1.0
# skipped       25      False      0.0
# failed        25      False      0.0
# max_score     25      False      NaN
# hits          25      False      NaN
#
#                                                          hits
# total                       {'value': 2139, 'relation': 'eq'}
# successful                                                NaN
# skipped                                                   NaN
# failed                                                    NaN
# max_score                                                 1.0
# hits        [{'_index': 'contents', '_id': '6349491dc4dbd3...

# %%
df=data.loc['hits']['hits']

# %%
type(df)
# Out:
# list

# %%
df1=pd.json_normalize(df)

# %%
df1
# Out:
#        _index                       _id  _score _source.@version  \
# 0    contents  6349491dc4dbd32b83faac95     1.0                1
# 1    contents  634947d2c4dbd32b83faac8e     1.0                1
# 2    contents  6349464cc4dbd32b83faac7c     1.0                1
# 3    contents  634942e7c4dbd32b83faac68     1.0                1
# 4    contents  6329754d8d07853a3016f6a9     1.0                1
# ..        ...                       ...     ...              ...
# 995  contents  627e219f3ab56f0f0ebe708f     1.0                1
# 996  contents  627e27163ab56f0f0ebe70ac     1.0                1
# 997  contents  627e2b163ab56f0f0ebe70b5     1.0                1
# 998  contents  627e30583ab56f0f0ebe70ba     1.0                1
# 999  contents  627e32943ab56f0f0ebe70bf     1.0                1
#
#     _source.document.updated_by  \
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# ...

# %%
cols=['_source.document.title','_source.document.summary','_source.document.type']

# %%
data1=df1[cols]

# %%
data1
# Out:
#                                 _source.document.title  \
# 0       Reminder - Optimus -  Best People Manager 2022
# 1    It starts this 23 October, till 26 October 202...
# 2    Congratulations Triveni Arun Bhalerao | Long S...
# 3     Long Service Awards - 5 years - Triveni Arun ...
# 4                                       tweets testing
# ..                                                 ...
# 995     Employee Referral Virtual Drive - 14 May, 2022
# 996   The Future Trends In Mobility And Transportation
# 997       The Keys to Pricing Power as Recession Looms
# 998  Intelligence and unified data governance in th...
# 999  Creating a defined data centric space with AI ...
#
#                               _source.document.summary _source.document.type
# 0    Today is the last day for voting (14th October...                TWEETS
# 1    Hope you are all set to attend Money 2020 USA ...                TWEETS
# ...

# %%
data1.rename(columns={'_source.document.title':'title','_source.document.summary':'summary','_source.document.type':'category'},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data1
# Out:
#                                                  title  \
# 0       Reminder - Optimus -  Best People Manager 2022
# 1    It starts this 23 October, till 26 October 202...
# 2    Congratulations Triveni Arun Bhalerao | Long S...
# 3     Long Service Awards - 5 years - Triveni Arun ...
# 4                                       tweets testing
# ..                                                 ...
# 995     Employee Referral Virtual Drive - 14 May, 2022
# 996   The Future Trends In Mobility And Transportation
# 997       The Keys to Pricing Power as Recession Looms
# 998  Intelligence and unified data governance in th...
# 999  Creating a defined data centric space with AI ...
#
#                                                summary             category
# 0    Today is the last day for voting (14th October...               TWEETS
# 1    Hope you are all set to attend Money 2020 USA ...               TWEETS
# ...

# %%
data1.to_csv('sample_dex_data.csv')
